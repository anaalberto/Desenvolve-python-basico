# %%
juros = 1.01
saldo = 500.0
rendimento1 = saldo * juros
rendimento2 = rendimento1 * juros
rendimento3 = rendimento2 * juros
print("Após 3 meses meu novo saldo é")
print(rendimento3)
# Out:
# Após 3 meses meu novo saldo é
# 515.1505

# %%
juros = 1.01
saldo = 500.0
print (saldo)
saldo = saldo * juros #505 rendimento 1
print (saldo)
saldo = saldo * juros #505 rendimento 2
print (saldo)
saldo = saldo * juros #505 rendimento 3
print("Após 3 meses meu novo saldo é")
print(rendimento3)
