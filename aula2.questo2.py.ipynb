# %%
# Entrada de dados
# genero, idade e tempo de serviço
genero = input ()
idade = int(input())
tempo = int(input())

#processamento
#A: Para mulheeres ter mais de 60 anos. Para homesn, 65.
#B: Ou ter rabalhado pelo menos 30 anos
#C: Ou ter  60 anos e trabalhado pelo menos 25.
a = (genero == 'f' and idade >= 60) or \
    (genero == 'm' and idade >= 65)

b = tempo > 30
c = idade >= 60 and tempo >= 25


pode_aposentar = a or b or c

#saída
print (a, b, c, pode_aposentar)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Entrada de dados
#       2 # genero, idade e tempo de serviço
#       3 genero = input ()
# ----> 4 idade = int (input())
#       5 tempo = int (input())
#       7 #processamento
#       8 #A: Para mulheeres ter mais de 60 anos. Para homesn, 65.
#       9 #B: Ou ter rabalhado pelo menos 30 anos
#      10 #C: Ou ter  60 anos e trabalhado pelo menos 25.
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'PyodideFuture'
